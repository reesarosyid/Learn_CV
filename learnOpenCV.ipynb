# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import cv2

# %%
img = cv2.imread("Data/puppy.jpg")
# Out:
# array([[[ 24,  46,  68],
#         [ 24,  46,  68],
#         [ 24,  46,  68],
#         ...,
#         [ 28,  51,  72],
#         [ 28,  51,  72],
#         [ 28,  51,  72]],
#
#        [[ 27,  50,  71],
#         [ 27,  50,  71],
#         [ 27,  50,  71],
#         ...,
#         [ 32,  54,  76],
#         [ 32,  54,  76],
#         [ 32,  54,  76]],
#
#        [[ 31,  53,  75],
#         [ 31,  53,  75],
#         [ 31,  53,  75],
#         ...,
#         [ 35,  58,  79],
#         [ 35,  58,  79],
#         [ 35,  58,  79]],
#
#        ...,
#
#        [[176, 206, 233],
#         [178, 207, 234],
#         [179, 208, 235],
#         ...,
#         [131, 171, 207],
#         [131, 171, 207],
#         [131, 171, 207]],
#
#        [[176, 208, 234],
#         [177, 209, 235],
#         [178, 210, 237],
#         ...,
#         [131, 171, 207],
#         [131, 171, 207],
#         [131, 171, 207]],
#
#        [[176, 208, 234],
#         [177, 209, 235],
#         [178, 210, 237],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1800, 3200, 3)

# %%
plt.imshow(img)
